# %%
from battle_query_api import *

print(get_b_unit_count())
# Out:
# alive_unit_count | initial_unit_count
# -----------------+-------------------
# 83               | 88

# %%
print(get_op_equipment_count())
# Out:
# available_equipment_count | initial_equipment_count
# --------------------------+------------------------
# 15                        | 15

# %%
print(get_b_unit_alive_by_interval(1))
# Out:
# bucket_time         | alive_unit_count
# --------------------+-----------------
# 2026-03-04 13:29:00 | 83
# 2026-03-04 13:30:00 | 83
# 2026-03-04 13:31:00 | 83
# 2026-03-04 13:32:00 | 83
# 2026-03-04 13:33:00 | 83
# 2026-03-04 13:34:00 | 83
# 2026-03-04 13:35:00 | 83
# 2026-03-04 13:36:00 | 83
# 2026-03-04 13:37:00 | 83
# 2026-03-04 13:38:00 | 82

# %%
print(get_op_ammo_total_by_interval(1))
# Out:
# bucket_time         | ammo_total
# --------------------+-----------
# 2026-03-04 13:34:00 | 6121
# 2026-03-04 13:35:00 | 64577
# 2026-03-04 13:36:00 | 82534
# 2026-03-04 13:37:00 | 207758
# 2026-03-04 13:38:00 | 154827

# %%
print(get_events_between("2026-03-04T13:35:00.000", "2026-03-04T13:38:00.000"))
# Out:
# datetime                | side | event_type     | targetunit   | shooter      | damage    | weapon                          | hitpoint     | unit         | gunner       | ammotype                             | muzzle                   | killer
# ------------------------+------+----------------+--------------+--------------+-----------+---------------------------------+--------------+--------------+--------------+--------------------------------------+--------------------------+-------------
# 2026-03-04T13:35:03.125 | b    | event_fired    | None         | None         | None      | RHS_M2_CROWS_M153_Abrams        | None         | b_1_t1_1_v1  | b_1_t1_1_u3  | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None
# 2026-03-04T13:35:08.806 | op   | event_dammaged | op_1_M2_1_v1 | b_1_t1_1_v1  | 0.3       | rhs_ammo_127x99_Ball_Tracer_Red | hitturret    | None         | None         | None                                 | None                     | None
# ...

# %%
print(get_events_recent_minutes(5))
# Out:
# datetime                | side | event_type     | targetunit   | shooter      | damage    | weapon                          | hitpoint     | unit         | gunner       | ammotype                             | muzzle                   | killer
# ------------------------+------+----------------+--------------+--------------+-----------+---------------------------------+--------------+--------------+--------------+--------------------------------------+--------------------------+-------------
# 2026-03-04T13:34:51.531 | b    | event_fired    | None         | None         | None      | rhs_weap_m256                   | None         | b_1_t1_1_v1  | b_1_t1_1_u2  | rhs_mag_M829A3                       | rhs_weap_m256            | None
# 2026-03-04T13:34:52.646 | op   | event_dammaged | op_1_i1_4_u6 | b_1_t1_1_v1  | 0.0203854 | rhs_ammo_M829A3                 | hitdiaphragm | None         | None         | None                                 | None                     | None
# ...

# %%
print(get_events_recent_rows(20))
# Out:
# datetime                | side | event_type     | targetunit   | shooter      | damage    | weapon                        | hitpoint   | unit         | gunner       | ammotype                             | muzzle                    | killer
# ------------------------+------+----------------+--------------+--------------+-----------+-------------------------------+------------+--------------+--------------+--------------------------------------+---------------------------+-------------
# 2026-03-04T13:38:23.374 | b    | event_dammaged | b_1_t1_3_v1  | op_1_M1_3_v1 | 0.185852  | rhs_ammo_3ubr11               | #light_l   | None         | None         | None                                 | None                      | None
# 2026-03-04T13:38:22.520 | op   | event_killed   | op_1_t2_1_v1 | None         | None      | None                          | None       | None         | None         | None                                 | None                      | b_1_m1_4_v1
# ...

# %%
print(get_observation_between("2025-03-03T14:00:00.000", "2025-03-03T14:10:00.000"))
# Out:
# (0 rows)
# datetime                | side | groupname | targetunit   | oldknowsabout | newknowsabout
# ------------------------+------+-----------+--------------+---------------+--------------
# 2026-03-04T13:30:39.209 | b    | b_1_m2_4  | b_1_m2_1_v1  | 0.00155721    | 0.0247615
# 2026-03-04T13:30:43.461 | b    | b_1_m2_2  | b_1_m2_1_v1  | 0.0048159     | 0.0537904
# 2026-03-04T13:30:48.650 | b    | b_1_i2_3  | b_1_m2_1_v1  | 0.517586      | 0.634668
# 2026-03-04T13:30:54.064 | b    | b_1_i1_4  | b_1_m2_1_v1  | 0.107275      | 0.141985
# 2026-03-04T13:30:59.510 | b    | b_1_i1_1  | b_1_m2_1_v1  | 0.484029      | 4.0
# 2026-03-04T13:31:04.508 | b    | b_1_i1_1  | b_1_m2_3_v1  | 0.0588356     | 0.0953224
# 2026-03-04T13:31:10.498 | b    | b_1_i1_1  | b_1_m2_3_v1  | 0.128275      | 0.216001
# 2026-03-04T13:31:15.659 | b    | b_1_i2_3  | b_1_i1_1_u2  | 0.323289      | 0.547353
# 2026-03-04T13:31:49.517 | b    | b_1_i1_1  | b_1_t1_2_v1  | 0.0573147     | 0.081321
# ...

# %%
print(get_observation_recent_minutes(5))
# Out:
# datetime                | side | groupname | targetunit   | oldknowsabout | newknowsabout
# ------------------------+------+-----------+--------------+---------------+--------------
# 2026-03-04T13:30:39.209 | b    | b_1_m2_4  | b_1_m2_1_v1  | 0.00155721    | 0.0247615
# 2026-03-04T13:30:43.461 | b    | b_1_m2_2  | b_1_m2_1_v1  | 0.0048159     | 0.0537904
# 2026-03-04T13:30:48.650 | b    | b_1_i2_3  | b_1_m2_1_v1  | 0.517586      | 0.634668
# 2026-03-04T13:30:54.064 | b    | b_1_i1_4  | b_1_m2_1_v1  | 0.107275      | 0.141985
# 2026-03-04T13:30:59.510 | b    | b_1_i1_1  | b_1_m2_1_v1  | 0.484029      | 4.0
# 2026-03-04T13:31:04.508 | b    | b_1_i1_1  | b_1_m2_3_v1  | 0.0588356     | 0.0953224
# 2026-03-04T13:31:10.498 | b    | b_1_i1_1  | b_1_m2_3_v1  | 0.128275      | 0.216001
# 2026-03-04T13:31:15.659 | b    | b_1_i2_3  | b_1_i1_1_u2  | 0.323289      | 0.547353
# 2026-03-04T13:31:49.517 | b    | b_1_i1_1  | b_1_t1_2_v1  | 0.0573147     | 0.081321
# ...

# %%
print(get_observation_recent_rows(20))
# Out:
# datetime                | side | groupname | targetunit   | oldknowsabout | newknowsabout
# ------------------------+------+-----------+--------------+---------------+--------------
# 2026-03-04T13:38:19.056 | op   | op_1_i3_2 | op_1_t1_2_v1 | 0.258981      | 1.35
# 2026-03-04T13:38:18.823 | b    | b_1_m2_2  | op_1_t1_3_v1 | 0.1           | 4.0
# 2026-03-04T13:38:13.813 | op   | op_1_m1_2 | op_1_t2_1_v1 | 0.210041      | 1.35
# 2026-03-04T13:38:13.806 | b    | b_1_t1_3  | op_1_t2_2_v2 | 7.24091e-07   | 4.0
# 2026-03-04T13:38:09.332 | op   | op_1_m3_3 | op_1_t2_1_v1 | 0.020877      | 1.35
# 2026-03-04T13:38:08.230 | b    | b_1_t1_3  | op_1_t2_1_v1 | 7.4327e-07    | 4.0
# 2026-03-04T13:38:03.353 | op   | op_1_m1_3 | b_1_t1_2_u2  | 0.0           | 1.0
# 2026-03-04T13:38:03.077 | b    | b_1_t1_2  | op_1_m1_2_u1 | 0.0           | 4.0
# 2026-03-04T13:37:57.749 | op   | op_1_m2_1 | op_1_t1_3_v1 | 0.00430071    | 0.016128
# ...
