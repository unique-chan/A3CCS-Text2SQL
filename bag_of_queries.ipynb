# %%
from bag_of_queries import *

# %% [markdown]
# 현재 가용 아군 유닛 수는?

# %%
print(get_unit_count(side='b', damage_threshold=0.5))
# Out:
# alive_unit_count | initial_unit_count
# -----------------+-------------------
# 78               | 88

# %% [markdown]
# 현재 가용 아군 차량 수는?

# %%
print(get_vehicle_count(side='b', damage_threshold=0.5))
# Out:
# available_vehicle_count | initial_vehicle_count
# ------------------------+----------------------
# 12                      | 12

# %% [markdown]
# 1분 간격, 현재 가용 아군 유닛 숫자 변화 추이?

# %%
print(get_unit_alive_by_interval(side='b', interval_minutes=1, damage_threshold=0.5))
# Out:
# bucket_time         | alive_unit_count
# --------------------+-----------------
# 2026-03-04 13:38:00 | 78
# 2026-03-04 13:37:00 | 78
# 2026-03-04 13:36:00 | 78
# 2026-03-04 13:35:00 | 78
# 2026-03-04 13:34:00 | 78
# 2026-03-04 13:33:00 | 78
# 2026-03-04 13:32:00 | 78
# 2026-03-04 13:31:00 | 78
# 2026-03-04 13:30:00 | 78
# 2026-03-04 13:29:00 | 78

# %% [markdown]
# 1분 간격, 현재 가용 아군 유닛 숫자 변화 추이? (단, 최대 5개 행만!)

# %%
print(get_unit_alive_by_interval(side='b', interval_minutes=1, damage_threshold=0.5, limit=5))
# Out:
# bucket_time         | alive_unit_count
# --------------------+-----------------
# 2026-03-04 13:38:00 | 78
# 2026-03-04 13:37:00 | 78
# 2026-03-04 13:36:00 | 78
# 2026-03-04 13:35:00 | 78
# 2026-03-04 13:34:00 | 78

# %% [markdown]
# 1분 간격, 현재 가용 아군 차량 숫자 변화 추이?

# %%
print(get_vehicle_available_by_interval('b', interval_minutes=1, damage_threshold=0.5))
# Out:
# bucket_time         | available_vehicle_count
# --------------------+------------------------
# 2026-03-04 13:38:00 | 12
# 2026-03-04 13:37:00 | 12
# 2026-03-04 13:36:00 | 12
# 2026-03-04 13:35:00 | 12
# 2026-03-04 13:34:00 | 12
# 2026-03-04 13:33:00 | 12
# 2026-03-04 13:32:00 | 12
# 2026-03-04 13:31:00 | 12
# 2026-03-04 13:30:00 | 12
# 2026-03-04 13:29:00 | 12

# %% [markdown]
# 1분 간격, 현재 가용 아군 차량 숫자 변화 추이? (단, 최대 5개 행만)

# %%
print(get_vehicle_available_by_interval('b', interval_minutes=1, damage_threshold=0.5, limit=5))
# Out:
# bucket_time         | available_vehicle_count
# --------------------+------------------------
# 2026-03-04 13:38:00 | 12
# 2026-03-04 13:37:00 | 12
# 2026-03-04 13:36:00 | 12
# 2026-03-04 13:35:00 | 12
# 2026-03-04 13:34:00 | 12

# %% [markdown]
# 1분 간격, 현재 가용 아군 탄약량 변화 추이?

# %%
print(get_ammo_total_by_interval('b', interval_minutes=1))
# Out:
# bucket_time         | ammo_total
# --------------------+-----------
# 2026-03-04 13:38:00 | 473220
# 2026-03-04 13:37:00 | 952673
# 2026-03-04 13:36:00 | 954718
# 2026-03-04 13:35:00 | 954753
# 2026-03-04 13:34:00 | 954788
# 2026-03-04 13:33:00 | 954789
# 2026-03-04 13:32:00 | 954789
# 2026-03-04 13:31:00 | 954789
# 2026-03-04 13:30:00 | 954789
# 2026-03-04 13:29:00 | 867990

# %% [markdown]
# 1분 간격, 현재 가용 아군 탄약량 변화 추이? (단, 최대 5개 행만)

# %%
print(get_ammo_total_by_interval('b', interval_minutes=1, limit=5))
# Out:
# bucket_time         | ammo_total
# --------------------+-----------
# 2026-03-04 13:38:00 | 473220
# 2026-03-04 13:37:00 | 952673
# 2026-03-04 13:36:00 | 954718
# 2026-03-04 13:35:00 | 954753
# 2026-03-04 13:34:00 | 954788

# %% [markdown]
# 13:30부터 13:35 사이에, 각 아군 그룹의 관심 객체에 대한 인지 정도 변화?

# %%
print(get_knowsaboutchanged_between("2026-03-04T13:30:00.000", "2026-03-04T13:35:00.000", source_side='b'))
# Out:
# datetime                | side | groupname | targetunit   | oldknowsabout | newknowsabout | seq
# ------------------------+------+-----------+--------------+---------------+---------------+----
# 2026-03-04T13:34:59.337 | b    | b_1_i2_3  | b_1_i2_2_u1  | 0.1085        | 0.146407      | 21
# 2026-03-04T13:34:59.337 | b    | b_1_i2_3  | b_1_i2_2_u5  | 0.0489292     | 0.0676184     | 22
# 2026-03-04T13:34:59.717 | b    | b_1_m2_1  | b_1_m1_1_v1  | 0.0468209     | 0.258304      | 25
# 2026-03-04T13:34:57.928 | b    | b_1_i2_2  | b_1_i2_3_u3  | 0.0563698     | 0.100449      | 14
# 2026-03-04T13:34:55.844 | b    | b_1_m2_4  | b_1_m2_2_v1  | 0.188648      | 0.246647      | 61
# 2026-03-04T13:34:54.702 | b    | b_1_m2_1  | b_1_m1_1_v1  | 0.013377      | 0.0468209     | 51
# 2026-03-04T13:34:53.357 | b    | b_1_i2_3  | b_1_i2_2_u6  | 0.0231359     | 0.0409829     | 41
# 2026-03-04T13:34:53.389 | b    | b_1_t1_1  | op_1_i2_2_u1 | 3.48159e-10   | 4.0           | 45
# 2026-03-04T13:34:52.944 | b    | b_1_t1_1  | op_1_M3_3_v1 | 6.08192e-07   | 4.0           | 37
# 2026-03-04T13:34:51.907 | b    | b_1_i2_2  | b_1_i2_3_u4  | 0.0158387     | 0.0300045     | 33
# 2026-03-04T13:34:51.062 | b    | b_1_t1_1  | op_1_M2_1_v1 | 6.37413e-07   | 4.0           | 18
# 2026-03-04T13:34:50.002 | b    | b_1_i2_4  | b_1_i2_3_u4  | 0.462411      | 4.0           | 25
# 2026-03-04T13:34:50.061 | b    | b_1_t1_1  | op_1_i1_4_u2 | 3.30224e-09   | 4.0           | 26
# 2026-03-04T13:34:50.397 | b    | b_1_t1_1  | op_1_i1_4_u6 | 3.27703e-09   | 4.0           | 34
# 2026-03-04T13:34:49.925 | b    | b_1_t1_1  | op_1_i1_2_u4 | 3.34077e-09   | 4.0           | 23
# 2026-03-04T13:34:47.024 | b    | b_1_i2_4  | b_1_i2_3_u4  | 0.273419      | 0.462411      | 8
# 2026-03-04T13:34:47.694 | b    | b_1_m2_1  | b_1_t1_2_v1  | 0.480947      | 4.0           | 10
# 2026-03-04T13:34:47.444 | b    | b_1_t1_2  | b_1_m2_1_v1  | 0.0728137     | 0.497091      | 9
# 2026-03-04T13:34:44.693 | b    | b_1_m2_1  | b_1_t1_2_v1  | 0.0993215     | 0.480947      | 25
# 2026-03-04T13:34:44.101 | b    | b_1_m2_2  | b_1_i1_2_u5  | 0.000571259   | 0.0109624     | 19
# 2026-03-04T13:34:43.280 | b    | b_1_i2_3  | b_1_i2_4_u3  | 0.0853322     | 0.115229      | 14
# 2026-03-04T13:34:42.008 | b    | b_1_i2_4  | b_1_i2_3_u4  | 0.20977       | 0.273419      | 7
# 2026-03-04T13:34:42.402 | b    | b_1_t1_2  | b_1_m2_1_v1  | 0.0141365     | 0.0728137     | 9
# 2026-03-04T13:34:39.670 | b    | b_1_m2_1  | b_1_t1_2_v1  | 0.0222973     | 0.0993215     | 24
# 2026-03-04T13:34:34.664 | b    | b_1_m2_1  | b_1_t1_2_v1  | 0.0069551     | 0.0222973     | 27
# 2026-03-04T13:34:29.011 | b    | b_1_i2_4  | b_1_i1_2_u3  | 0.568048      | 4.0           | 53
# 2026-03-04T13:34:29.011 | b    | b_1_i2_4  | b_1_i1_2_u5  | 0.547119      | 4.0           | 52
# 2026-03-04T13:34:29.011 | b    | b_1_i2_4  | b_1_i2_2_u1  | 0.538581      | 4.0           | 54
# 2026-03-04T13:34:29.498 | b    | b_1_t1_4  | b_1_m2_1_v1  | 0.373615      | 4.0           | 55
# 2026-03-04T13:34:27.674 | b    | b_1_m2_1  | b_1_t1_4_v1  | 0.661602      | 4.0           | 36
# 2026-03-04T13:34:26.951 | b    | b_1_i1_2  | b_1_i2_2_u2  | 0.545063      | 4.0           | 32
# 2026-03-04T13:34:26.951 | b    | b_1_i1_2  | b_1_i2_4_u4  | 0.386821      | 4.0           | 33
# 2026-03-04T13:34:26.489 | b    | b_1_t1_4  | b_1_m2_1_v1  | 0.136155      | 0.373615      | 31
# 2026-03-04T13:34:25.672 | b    | b_1_i1_4  | b_1_i2_3_u2  | 0.44981       | 4.0           | 14
# 2026-03-04T13:34:25.672 | b    | b_1_i1_4  | b_1_i2_4_u5  | 0.673974      | 4.0           | 12
# 2026-03-04T13:34:25.672 | b    | b_1_i1_4  | b_1_i2_4_u6  | 0.544184      | 4.0           | 13
# 2026-03-04T13:34:25.872 | b    | b_1_i2_2  | b_1_i1_2_u2  | 0.282207      | 4.0           | 15
# 2026-03-04T13:34:25.872 | b    | b_1_i2_2  | b_1_i2_1_u5  | 0.546274      | 4.0           | 18
# 2026-03-04T13:34:25.872 | b    | b_1_i2_2  | b_1_i2_1_u6  | 0.408234      | 4.0           | 16
# 2026-03-04T13:34:25.872 | b    | b_1_i2_2  | b_1_i2_4_u3  | 0.624852      | 4.0           | 17
# 2026-03-04T13:34:24.048 | b    | b_1_i2_4  | b_1_i1_2_u3  | 0.111791      | 0.568048      | 54
# 2026-03-04T13:34:23.004 | b    | b_1_i1_2  | b_1_i2_2_u2  | 0.445148      | 0.545063      | 42
# 2026-03-04T13:34:23.004 | b    | b_1_i2_1  | b_1_i2_2_u4  | 0.0602839     | 0.156586      | 38
# 2026-03-04T13:34:22.955 | b    | b_1_i2_2  | b_1_i1_2_u2  | 0.131919      | 0.282207      | 35
# 2026-03-04T13:34:22.954 | b    | b_1_i2_2  | b_1_i1_2_u2  | 0.108975      | 0.131919      | 34
# 2026-03-04T13:34:22.954 | b    | b_1_i2_2  | b_1_i2_1_u5  | 0.357727      | 0.546274      | 33
# 2026-03-04T13:34:22.954 | b    | b_1_i2_2  | b_1_i2_4_u3  | 0.479343      | 0.624852      | 32
# 2026-03-04T13:34:22.671 | b    | b_1_m2_1  | b_1_t1_4_v1  | 0.117598      | 0.661602      | 20
# 2026-03-04T13:34:21.466 | b    | b_1_t1_4  | b_1_m2_1_v1  | 0.0127777     | 0.136155      | 19
# 2026-03-04T13:34:18.077 | b    | b_1_i2_4  | b_1_i1_2_u5  | 0.170952      | 0.547119      | 47
# ... (showing the first 50 rows of 1008 rows.)

# %% [markdown]
# 13:30부터 13:35 사이에, 각 아군 그룹의 "적군 (op)" 관심 객체에 대한 인지 정도 변화?

# %%
print(get_knowsaboutchanged_between("2026-03-04T13:30:00.000", "2026-03-04T13:35:00.000", source_side='b', target_side='op'))
# Out:
# datetime                | side | groupname | targetunit   | oldknowsabout | newknowsabout | seq
# ------------------------+------+-----------+--------------+---------------+---------------+----
# 2026-03-04T13:34:53.389 | b    | b_1_t1_1  | op_1_i2_2_u1 | 3.48159e-10   | 4.0           | 45
# 2026-03-04T13:34:52.944 | b    | b_1_t1_1  | op_1_M3_3_v1 | 6.08192e-07   | 4.0           | 37
# 2026-03-04T13:34:51.062 | b    | b_1_t1_1  | op_1_M2_1_v1 | 6.37413e-07   | 4.0           | 18
# 2026-03-04T13:34:50.061 | b    | b_1_t1_1  | op_1_i1_4_u2 | 3.30224e-09   | 4.0           | 26
# 2026-03-04T13:34:50.397 | b    | b_1_t1_1  | op_1_i1_4_u6 | 3.27703e-09   | 4.0           | 34
# 2026-03-04T13:34:49.925 | b    | b_1_t1_1  | op_1_i1_2_u4 | 3.34077e-09   | 4.0           | 23

# %% [markdown]
# 최근 3분간 각 아/적군 그룹의 관심 객체에 대한 인지 정도 변화?

# %%
print(get_knowsaboutchanged_recent_minutes(3))
# Out:
# datetime                | side | groupname | targetunit   | oldknowsabout | newknowsabout | seq
# ------------------------+------+-----------+--------------+---------------+---------------+----
# 2026-03-04T13:38:24.051 | b    | b_1_t1_4  | op_1_t2_2_v2 | 6.95358e-07   | 4.0           | 110
# 2026-03-04T13:38:24.062 | op   | op_1_i2_3 | op_1_t2_2_v2 | 0.0644119     | 1.35          | 87
# 2026-03-04T13:38:23.579 | b    | b_1_i1_3  | b_1_i2_2_u3  | 0.0443418     | 0.0836092     | 91
# 2026-03-04T13:38:23.207 | b    | b_1_t1_3  | b_1_t1_4_v1  | 0.0317795     | 0.499491      | 57
# 2026-03-04T13:38:23.375 | b    | b_1_t1_3  | op_1_m1_3_u2 | 1.0           | 4.0           | 90
# 2026-03-04T13:38:23.142 | b    | b_1_t1_3  | op_1_t2_2_u3 | 1.0           | 4.0           | 56
# 2026-03-04T13:38:23.264 | b    | b_1_t1_4  | b_1_t1_3_v1  | 0.0936617     | 1.35          | 59
# 2026-03-04T13:38:23.799 | op   | op_1_m3_1 | op_1_t2_2_v2 | 0.0169236     | 1.10798       | 86
# 2026-03-04T13:38:23.132 | op   | op_1_t1_1 | b_1_t1_2_u2  | 4.12666e-07   | 4.0           | 69
# 2026-03-04T13:38:22.992 | b    | b_1_i1_1  | op_1_t1_3_v1 | 0.1           | 4.0           | 54
# 2026-03-04T13:38:22.874 | op   | op_1_i2_1 | op_1_t2_2_v2 | 0.0555518     | 1.35          | 67
# 2026-03-04T13:38:22.349 | op   | op_1_i2_2 | op_1_t2_2_v2 | 0.0873891     | 1.35          | 61
# 2026-03-04T13:38:22.932 | op   | op_1_m1_1 | op_1_t2_2_v2 | 0.00184146    | 0.122764      | 68
# 2026-03-04T13:38:22.808 | op   | op_1_t1_1 | op_1_t2_2_v2 | 0.00149813    | 0.099875      | 66
# 2026-03-04T13:38:22.623 | op   | op_1_t1_3 | op_1_t2_2_v2 | 0.00197936    | 0.131958      | 62
# 2026-03-04T13:38:21.087 | op   | op_1_i3_1 | op_1_t1_2_v1 | 0.256341      | 1.35          | 57
# 2026-03-04T13:38:20.657 | b    | b_1_i1_2  | b_1_m2_4_v1  | 0.437771      | 4.0           | 34
# 2026-03-04T13:38:20.657 | b    | b_1_i1_2  | op_1_t1_3_v1 | 0.1           | 4.0           | 33
# 2026-03-04T13:38:20.608 | b    | b_1_i1_3  | b_1_i2_1_u1  | 0.0233831     | 0.0496421     | 29
# 2026-03-04T13:38:20.608 | b    | b_1_i1_3  | b_1_i2_1_u5  | 0.115991      | 0.53982       | 31
# 2026-03-04T13:38:20.608 | b    | b_1_i1_3  | b_1_i2_2_u5  | 0.0377906     | 0.0582731     | 30
# 2026-03-04T13:38:20.443 | b    | b_1_i1_4  | b_1_m2_1_v1  | 0.302519      | 0.313313      | 19
# 2026-03-04T13:38:20.562 | b    | b_1_t1_1  | op_1_t1_3_v1 | 0.1           | 4.0           | 26
# 2026-03-04T13:38:20.152 | b    | b_1_t1_2  | op_1_t1_2_v1 | 0.00636086    | 0.0513019     | 13
# 2026-03-04T13:38:20.886 | b    | b_1_t1_4  | op_1_t1_3_u1 | 1.0           | 4.0           | 42
# 2026-03-04T13:38:20.072 | op   | op_1_i3_3 | op_1_t1_2_v1 | 0.242462      | 1.35          | 22
# 2026-03-04T13:38:20.937 | op   | op_1_m1_1 | b_1_t1_2_u2  | 4.23402e-07   | 4.0           | 56
# 2026-03-04T13:38:20.791 | op   | op_1_m2_1 | op_1_t1_2_v1 | 0.0054884     | 0.042866      | 55
# 2026-03-04T13:38:20.395 | op   | op_1_m2_2 | op_1_t1_2_v1 | 0.00646652    | 0.0505148     | 30
# 2026-03-04T13:38:20.657 | op   | op_1_m3_1 | op_1_t1_1_v1 | 0.782734      | 4.0           | 53
# 2026-03-04T13:38:20.657 | op   | op_1_m3_1 | op_1_t1_3_v1 | 0.557525      | 4.0           | 52
# 2026-03-04T13:38:20.657 | op   | op_1_m3_1 | op_1_t2_1_v1 | 1.31506       | 4.0           | 54
# 2026-03-04T13:38:20.014 | op   | op_1_m3_2 | op_1_t1_2_v1 | 0.00398333    | 0.031115      | 11
# 2026-03-04T13:38:20.396 | op   | op_1_m3_3 | op_1_t1_2_v1 | 0.241516      | 1.35          | 34
# 2026-03-04T13:38:20.562 | op   | op_1_t1_3 | op_1_t1_2_v1 | 0.748375      | 4.0           | 51
# 2026-03-04T13:38:19.804 | b    | b_1_i2_4  | b_1_i1_3_u5  | 0.600732      | 4.0           | 9
# 2026-03-04T13:38:19.804 | b    | b_1_i2_4  | b_1_i1_3_u6  | 0.593912      | 4.0           | 11
# 2026-03-04T13:38:19.804 | b    | b_1_i2_4  | b_1_i2_1_u2  | 0.547746      | 4.0           | 10
# 2026-03-04T13:38:19.804 | b    | b_1_i2_4  | op_1_t1_3_v1 | 0.1           | 4.0           | 8
# 2026-03-04T13:38:19.428 | b    | b_1_m2_1  | op_1_t1_3_v1 | 0.1           | 4.0           | 3
# 2026-03-04T13:38:19.237 | b    | b_1_t1_4  | op_1_t1_3_v1 | 0.1           | 4.0           | 2
# 2026-03-04T13:38:19.056 | op   | op_1_i3_2 | op_1_t1_2_v1 | 0.258981      | 1.35          | 3
# 2026-03-04T13:38:19.373 | op   | op_1_m1_3 | op_1_t1_2_v1 | 0.0156328     | 0.122151      | 7
# 2026-03-04T13:38:19.373 | op   | op_1_m1_3 | op_1_t1_3_v1 | 0.0148753     | 0.0557822     | 8
# 2026-03-04T13:38:18.369 | b    | b_1_i1_4  | b_1_m2_2_v1  | 1.35          | 4.0           | 163
# 2026-03-04T13:38:18.369 | b    | b_1_i1_4  | op_1_t1_3_v1 | 0.1           | 4.0           | 162
# 2026-03-04T13:38:18.961 | b    | b_1_i2_3  | op_1_t1_3_v1 | 0.1           | 4.0           | 1
# 2026-03-04T13:38:18.571 | b    | b_1_m1_4  | op_1_t1_3_u2 | 1.0           | 4.0           | 165
# 2026-03-04T13:38:18.823 | b    | b_1_m2_2  | op_1_t1_3_v1 | 0.1           | 4.0           | 0
# 2026-03-04T13:38:18.152 | b    | b_1_t1_3  | b_1_t1_4_v1  | 0.0128044     | 0.0317795     | 156
# ... (showing the first 50 rows of 964 rows.)

# %% [markdown]
# 최근 3분간 각 아군 그룹의 "적군 (op)" 관심 객체에 대한 인지 정도 변화?

# %%
print(get_knowsaboutchanged_recent_minutes(3, source_side='b', target_side='op'))
# Out:
# datetime                | side | groupname | targetunit   | oldknowsabout | newknowsabout | seq
# ------------------------+------+-----------+--------------+---------------+---------------+----
# 2026-03-04T13:38:24.051 | b    | b_1_t1_4  | op_1_t2_2_v2 | 6.95358e-07   | 4.0           | 110
# 2026-03-04T13:38:23.375 | b    | b_1_t1_3  | op_1_m1_3_u2 | 1.0           | 4.0           | 90
# 2026-03-04T13:38:23.142 | b    | b_1_t1_3  | op_1_t2_2_u3 | 1.0           | 4.0           | 56
# 2026-03-04T13:38:22.992 | b    | b_1_i1_1  | op_1_t1_3_v1 | 0.1           | 4.0           | 54
# 2026-03-04T13:38:20.657 | b    | b_1_i1_2  | op_1_t1_3_v1 | 0.1           | 4.0           | 33
# 2026-03-04T13:38:20.562 | b    | b_1_t1_1  | op_1_t1_3_v1 | 0.1           | 4.0           | 26
# 2026-03-04T13:38:20.152 | b    | b_1_t1_2  | op_1_t1_2_v1 | 0.00636086    | 0.0513019     | 13
# 2026-03-04T13:38:20.886 | b    | b_1_t1_4  | op_1_t1_3_u1 | 1.0           | 4.0           | 42
# 2026-03-04T13:38:19.804 | b    | b_1_i2_4  | op_1_t1_3_v1 | 0.1           | 4.0           | 8
# 2026-03-04T13:38:19.428 | b    | b_1_m2_1  | op_1_t1_3_v1 | 0.1           | 4.0           | 3
# 2026-03-04T13:38:19.237 | b    | b_1_t1_4  | op_1_t1_3_v1 | 0.1           | 4.0           | 2
# 2026-03-04T13:38:18.369 | b    | b_1_i1_4  | op_1_t1_3_v1 | 0.1           | 4.0           | 162
# 2026-03-04T13:38:18.961 | b    | b_1_i2_3  | op_1_t1_3_v1 | 0.1           | 4.0           | 1
# 2026-03-04T13:38:18.571 | b    | b_1_m1_4  | op_1_t1_3_u2 | 1.0           | 4.0           | 165
# 2026-03-04T13:38:18.823 | b    | b_1_m2_2  | op_1_t1_3_v1 | 0.1           | 4.0           | 0
# 2026-03-04T13:38:17.601 | b    | b_1_i2_2  | op_1_t1_3_v1 | 0.1           | 4.0           | 135
# 2026-03-04T13:38:17.601 | b    | b_1_m1_1  | op_1_t1_3_v1 | 0.1           | 4.0           | 134
# 2026-03-04T13:38:17.322 | b    | b_1_m2_3  | op_1_t1_3_v1 | 0.1           | 4.0           | 133
# 2026-03-04T13:38:16.508 | b    | b_1_i1_3  | op_1_t1_3_v1 | 0.1           | 4.0           | 127
# 2026-03-04T13:38:16.664 | b    | b_1_i2_1  | op_1_t1_3_v1 | 0.1           | 4.0           | 129
# 2026-03-04T13:38:16.040 | b    | b_1_m1_4  | op_1_t1_3_v1 | 0.1           | 4.0           | 93
# 2026-03-04T13:38:16.207 | b    | b_1_t1_3  | op_1_t1_3_u1 | 1.0           | 4.0           | 95
# 2026-03-04T13:38:15.811 | b    | b_1_t1_3  | op_1_t1_2_u2 | 1.0           | 4.0           | 81
# 2026-03-04T13:38:15.794 | b    | b_1_t1_3  | op_1_t1_2_v1 | 7.22798e-07   | 1.5           | 79
# 2026-03-04T13:38:14.492 | b    | b_1_m2_4  | op_1_t1_3_v1 | 0.1           | 4.0           | 14
# 2026-03-04T13:38:13.072 | b    | b_1_t1_3  | op_1_i3_1_u1 | 3.7821e-10    | 4.0           | 116
# 2026-03-04T13:38:13.806 | b    | b_1_t1_3  | op_1_t2_2_v2 | 7.24091e-07   | 4.0           | 0
# 2026-03-04T13:38:12.382 | b    | b_1_t1_3  | op_1_t1_1_u3 | 1.0           | 4.0           | 114
# 2026-03-04T13:38:12.404 | b    | b_1_t1_3  | op_1_t1_1_v1 | 7.44176e-07   | 1.5           | 115
# 2026-03-04T13:38:10.456 | b    | b_1_i1_1  | op_1_t1_3_v1 | 6.42039e-05   | 0.1           | 61
# 2026-03-04T13:38:10.455 | b    | b_1_i1_2  | op_1_t1_3_v1 | 0.0059129     | 0.1           | 59
# 2026-03-04T13:38:10.456 | b    | b_1_i1_3  | op_1_t1_3_v1 | 0.0042639     | 0.1           | 66
# 2026-03-04T13:38:10.455 | b    | b_1_i1_4  | op_1_t1_3_v1 | 0.00651529    | 0.1           | 56
# 2026-03-04T13:38:10.456 | b    | b_1_i2_1  | op_1_t1_3_v1 | 0.00114487    | 0.1           | 65
# 2026-03-04T13:38:10.456 | b    | b_1_i2_2  | op_1_t1_3_v1 | 0.00117589    | 0.1           | 64
# 2026-03-04T13:38:10.456 | b    | b_1_i2_3  | op_1_t1_3_v1 | 0.00453454    | 0.1           | 62
# 2026-03-04T13:38:10.456 | b    | b_1_i2_4  | op_1_t1_3_v1 | 0.00457918    | 0.1           | 63
# 2026-03-04T13:38:10.453 | b    | b_1_m1_1  | op_1_t1_3_v1 | 5.93592e-07   | 0.1           | 53
# 2026-03-04T13:38:10.455 | b    | b_1_m1_4  | op_1_t1_3_v1 | 5.9916e-07    | 0.1           | 55
# 2026-03-04T13:38:10.456 | b    | b_1_m2_1  | op_1_t1_3_v1 | 1.23579e-06   | 0.1           | 60
# 2026-03-04T13:38:10.455 | b    | b_1_m2_2  | op_1_t1_3_v1 | 0.000118683   | 0.1           | 58
# 2026-03-04T13:38:10.457 | b    | b_1_m2_3  | op_1_t1_3_v1 | 2.28852e-05   | 0.1           | 67
# 2026-03-04T13:38:10.455 | b    | b_1_m2_4  | op_1_t1_3_v1 | 3.48829e-05   | 0.1           | 57
# 2026-03-04T13:38:10.452 | b    | b_1_t1_1  | op_1_t1_3_v1 | 0.0012972     | 0.1           | 52
# 2026-03-04T13:38:10.404 | b    | b_1_t1_2  | op_1_t1_3_v1 | 1.5           | 4.0           | 51
# 2026-03-04T13:38:10.057 | b    | b_1_t1_2  | op_1_t2_1_v1 | 0.000536345   | 0.025984      | 49
# 2026-03-04T13:38:10.526 | b    | b_1_t1_3  | op_1_t2_1_u3 | 1.0           | 4.0           | 69
# 2026-03-04T13:38:10.454 | b    | b_1_t1_4  | op_1_t1_3_v1 | 6.78651e-07   | 0.1           | 54
# 2026-03-04T13:38:09.057 | b    | b_1_t1_2  | op_1_t1_1_v1 | 0.000387933   | 0.0250844     | 35
# 2026-03-04T13:38:09.922 | b    | b_1_t1_2  | op_1_t2_2_v2 | 0.000371233   | 4.0           | 48
# ... (showing the first 50 rows of 129 rows.)

# %% [markdown]
# 최근 각 아군 그룹의 관심 객체에 대한 인지 정도 변화 이벤트 10개만 뽑아보면?

# %%
print(get_knowsaboutchanged_recent_rows(20, source_side='b'))
# Out:
# datetime                | side | groupname | targetunit   | oldknowsabout | newknowsabout | seq
# ------------------------+------+-----------+--------------+---------------+---------------+----
# 2026-03-04T13:38:24.051 | b    | b_1_t1_4  | op_1_t2_2_v2 | 6.95358e-07   | 4.0           | 110
# 2026-03-04T13:38:23.579 | b    | b_1_i1_3  | b_1_i2_2_u3  | 0.0443418     | 0.0836092     | 91
# 2026-03-04T13:38:23.207 | b    | b_1_t1_3  | b_1_t1_4_v1  | 0.0317795     | 0.499491      | 57
# 2026-03-04T13:38:23.375 | b    | b_1_t1_3  | op_1_m1_3_u2 | 1.0           | 4.0           | 90
# 2026-03-04T13:38:23.142 | b    | b_1_t1_3  | op_1_t2_2_u3 | 1.0           | 4.0           | 56
# 2026-03-04T13:38:23.264 | b    | b_1_t1_4  | b_1_t1_3_v1  | 0.0936617     | 1.35          | 59
# 2026-03-04T13:38:22.992 | b    | b_1_i1_1  | op_1_t1_3_v1 | 0.1           | 4.0           | 54
# 2026-03-04T13:38:20.657 | b    | b_1_i1_2  | b_1_m2_4_v1  | 0.437771      | 4.0           | 34
# 2026-03-04T13:38:20.657 | b    | b_1_i1_2  | op_1_t1_3_v1 | 0.1           | 4.0           | 33
# 2026-03-04T13:38:20.608 | b    | b_1_i1_3  | b_1_i2_1_u1  | 0.0233831     | 0.0496421     | 29
# 2026-03-04T13:38:20.608 | b    | b_1_i1_3  | b_1_i2_1_u5  | 0.115991      | 0.53982       | 31
# 2026-03-04T13:38:20.608 | b    | b_1_i1_3  | b_1_i2_2_u5  | 0.0377906     | 0.0582731     | 30
# 2026-03-04T13:38:20.443 | b    | b_1_i1_4  | b_1_m2_1_v1  | 0.302519      | 0.313313      | 19
# 2026-03-04T13:38:20.562 | b    | b_1_t1_1  | op_1_t1_3_v1 | 0.1           | 4.0           | 26
# 2026-03-04T13:38:20.152 | b    | b_1_t1_2  | op_1_t1_2_v1 | 0.00636086    | 0.0513019     | 13
# 2026-03-04T13:38:20.886 | b    | b_1_t1_4  | op_1_t1_3_u1 | 1.0           | 4.0           | 42
# 2026-03-04T13:38:19.804 | b    | b_1_i2_4  | b_1_i1_3_u5  | 0.600732      | 4.0           | 9
# 2026-03-04T13:38:19.804 | b    | b_1_i2_4  | b_1_i1_3_u6  | 0.593912      | 4.0           | 11
# 2026-03-04T13:38:19.804 | b    | b_1_i2_4  | b_1_i2_1_u2  | 0.547746      | 4.0           | 10
# 2026-03-04T13:38:19.804 | b    | b_1_i2_4  | op_1_t1_3_v1 | 0.1           | 4.0           | 8

# %% [markdown]
# 최근 각 아/적군 그룹의 관심 객체에 대한 인지 정도 변화 이벤트 10개만 뽑아보면?

# %%
print(get_knowsaboutchanged_recent_rows(20))
# Out:
# datetime                | side | groupname | targetunit   | oldknowsabout | newknowsabout | seq
# ------------------------+------+-----------+--------------+---------------+---------------+----
# 2026-03-04T13:38:24.051 | b    | b_1_t1_4  | op_1_t2_2_v2 | 6.95358e-07   | 4.0           | 110
# 2026-03-04T13:38:24.062 | op   | op_1_i2_3 | op_1_t2_2_v2 | 0.0644119     | 1.35          | 87
# 2026-03-04T13:38:23.579 | b    | b_1_i1_3  | b_1_i2_2_u3  | 0.0443418     | 0.0836092     | 91
# 2026-03-04T13:38:23.207 | b    | b_1_t1_3  | b_1_t1_4_v1  | 0.0317795     | 0.499491      | 57
# 2026-03-04T13:38:23.375 | b    | b_1_t1_3  | op_1_m1_3_u2 | 1.0           | 4.0           | 90
# 2026-03-04T13:38:23.142 | b    | b_1_t1_3  | op_1_t2_2_u3 | 1.0           | 4.0           | 56
# 2026-03-04T13:38:23.264 | b    | b_1_t1_4  | b_1_t1_3_v1  | 0.0936617     | 1.35          | 59
# 2026-03-04T13:38:23.799 | op   | op_1_m3_1 | op_1_t2_2_v2 | 0.0169236     | 1.10798       | 86
# 2026-03-04T13:38:23.132 | op   | op_1_t1_1 | b_1_t1_2_u2  | 4.12666e-07   | 4.0           | 69
# 2026-03-04T13:38:22.992 | b    | b_1_i1_1  | op_1_t1_3_v1 | 0.1           | 4.0           | 54
# 2026-03-04T13:38:22.874 | op   | op_1_i2_1 | op_1_t2_2_v2 | 0.0555518     | 1.35          | 67
# 2026-03-04T13:38:22.349 | op   | op_1_i2_2 | op_1_t2_2_v2 | 0.0873891     | 1.35          | 61
# 2026-03-04T13:38:22.932 | op   | op_1_m1_1 | op_1_t2_2_v2 | 0.00184146    | 0.122764      | 68
# 2026-03-04T13:38:22.808 | op   | op_1_t1_1 | op_1_t2_2_v2 | 0.00149813    | 0.099875      | 66
# 2026-03-04T13:38:22.623 | op   | op_1_t1_3 | op_1_t2_2_v2 | 0.00197936    | 0.131958      | 62
# 2026-03-04T13:38:21.087 | op   | op_1_i3_1 | op_1_t1_2_v1 | 0.256341      | 1.35          | 57
# 2026-03-04T13:38:20.657 | b    | b_1_i1_2  | b_1_m2_4_v1  | 0.437771      | 4.0           | 34
# 2026-03-04T13:38:20.657 | b    | b_1_i1_2  | op_1_t1_3_v1 | 0.1           | 4.0           | 33
# 2026-03-04T13:38:20.608 | b    | b_1_i1_3  | b_1_i2_1_u1  | 0.0233831     | 0.0496421     | 29
# 2026-03-04T13:38:20.608 | b    | b_1_i1_3  | b_1_i2_1_u5  | 0.115991      | 0.53982       | 31

# %% [markdown]
# 최근 3분간 발생한 이벤트?

# %%
print(get_events_recent_minutes(3))
# Out:
# datetime                | side | event_type     | targetunit   | shooter      | damage    | weapon                   | hitpoint                                                           | unit         | gunner       | ammotype                             | muzzle                   | killer      | seq
# ------------------------+------+----------------+--------------+--------------+-----------+--------------------------+--------------------------------------------------------------------+--------------+--------------+--------------------------------------+--------------------------+-------------+----
# 2026-03-04T13:38:24.093 | op   | event_fired    | None         | None         | None      | rhs_weap_nsvt_t90m_RWS   | None                                                               | op_1_t2_2_v2 | op_1_t2_2_u3 | rhs_mag_127x108mm_150                | rhs_weap_nsvt_t90m_RWS   | None        | 22
# 2026-03-04T13:38:23.375 | b    | event_dammaged | b_1_t1_3_v1  | op_1_M1_3_v1 | 1.0       | rhs_ammo_3ubr11          | #light_r                                                           | None         | None         | None                                 | None                     | None        | 3
# 2026-03-04T13:38:23.374 | b    | event_dammaged | b_1_t1_3_v1  | op_1_M1_3_v1 | 1.0       | rhs_ammo_3ubr11          | #light_l,#light_r                                                  | None         | None         | None                                 | None                     | None        | 2
# 2026-03-04T13:38:23.978 | op   | event_fired    | None         | None         | None      | rhs_weap_nsvt_t90m_RWS   | None                                                               | op_1_t2_2_v2 | op_1_t2_2_u3 | rhs_mag_127x108mm_150                | rhs_weap_nsvt_t90m_RWS   | None        | 21
# 2026-03-04T13:38:23.839 | op   | event_fired    | None         | None         | None      | rhs_weap_nsvt_t90m_RWS   | None                                                               | op_1_t2_2_v2 | op_1_t2_2_u3 | rhs_mag_127x108mm_150                | rhs_weap_nsvt_t90m_RWS   | None        | 20
# 2026-03-04T13:38:23.692 | op   | event_fired    | None         | None         | None      | rhs_weap_nsvt_t90m_RWS   | None                                                               | op_1_t2_2_v2 | op_1_t2_2_u3 | rhs_mag_127x108mm_150                | rhs_weap_nsvt_t90m_RWS   | None        | 19
# 2026-03-04T13:38:22.782 | op   | event_fired    | None         | None         | None      | rhs_weap_2a72            | None                                                               | op_1_M1_3_v1 | op_1_m1_3_u2 | rhs_mag_3ubr11_195                   | HE                       | None        | 18
# 2026-03-04T13:38:22.373 | op   | event_fired    | None         | None         | None      | rhs_weap_2a72            | None                                                               | op_1_M1_3_v1 | op_1_m1_3_u2 | rhs_mag_3ubr11_195                   | HE                       | None        | 17
# 2026-03-04T13:38:22.174 | op   | event_fired    | None         | None         | None      | rhs_weap_2a72            | None                                                               | op_1_M1_3_v1 | op_1_m1_3_u2 | rhs_mag_3ubr11_195                   | HE                       | None        | 16
# 2026-03-04T13:38:22.074 | op   | event_fired    | None         | None         | None      | rhs_weap_nsvt_t90m_RWS   | None                                                               | op_1_t2_2_v2 | op_1_t2_2_u3 | rhs_mag_127x108mm_150                | rhs_weap_nsvt_t90m_RWS   | None        | 15
# 2026-03-04T13:38:22.025 | op   | event_fired    | None         | None         | None      | rhs_weap_nsvt_t90m_RWS   | None                                                               | op_1_t1_3_v1 | op_1_t1_3_u1 | rhs_mag_127x108mm_150                | rhs_weap_nsvt_t90m_RWS   | None        | 14
# 2026-03-04T13:38:22.653 | b    | event_fired    | None         | None         | None      | RHS_M2_CROWS_M153_Abrams | None                                                               | b_1_t1_3_v1  | b_1_t1_3_u2  | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 13
# 2026-03-04T13:38:22.462 | b    | event_fired    | None         | None         | None      | RHS_weap_M242BC          | None                                                               | b_1_m1_3_v1  | b_1_m1_3_u2  | rhs_mag_70Rnd_25mm_M242_APFSDS       | AP                       | None        | 12
# 2026-03-04T13:38:22.415 | b    | event_fired    | None         | None         | None      | RHS_M2_CROWS_M153_Abrams | None                                                               | b_1_t1_3_v1  | b_1_t1_3_u2  | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 11
# 2026-03-04T13:38:22.322 | b    | event_fired    | None         | None         | None      | RHS_M2_CROWS_M153_Abrams | None                                                               | b_1_t1_3_v1  | b_1_t1_3_u2  | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 10
# 2026-03-04T13:38:22.223 | b    | event_fired    | None         | None         | None      | RHS_M2_CROWS_M153_Abrams | None                                                               | b_1_t1_3_v1  | b_1_t1_3_u2  | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 9
# 2026-03-04T13:38:22.522 | op   | event_killed   | op_1_t2_1_u2 | None         | None      | None                     | None                                                               | None         | None         | None                                 | None                     | b_1_m1_4_v1 | 1
# 2026-03-04T13:38:22.520 | op   | event_killed   | op_1_t2_1_v1 | None         | None      | None                     | None                                                               | None         | None         | None                                 | None                     | b_1_m1_4_v1 | 0
# 2026-03-04T13:38:21.887 | op   | event_fired    | None         | None         | None      | rhs_weap_nsvt_t90m_RWS   | None                                                               | op_1_t2_2_v2 | op_1_t2_2_u3 | rhs_mag_127x108mm_150                | rhs_weap_nsvt_t90m_RWS   | None        | 13
# 2026-03-04T13:38:21.843 | op   | event_fired    | None         | None         | None      | rhs_weap_nsvt_t90m_RWS   | None                                                               | op_1_t1_3_v1 | op_1_t1_3_u1 | rhs_mag_127x108mm_150                | rhs_weap_nsvt_t90m_RWS   | None        | 12
# 2026-03-04T13:38:21.802 | op   | event_fired    | None         | None         | None      | rhs_weap_2a72            | None                                                               | op_1_M1_3_v1 | op_1_m1_3_u2 | rhs_mag_3ubr11_195                   | HE                       | None        | 11
# 2026-03-04T13:38:21.718 | op   | event_fired    | None         | None         | None      | rhs_weap_nsvt_t90m_RWS   | None                                                               | op_1_t2_2_v2 | op_1_t2_2_u3 | rhs_mag_127x108mm_150                | rhs_weap_nsvt_t90m_RWS   | None        | 10
# 2026-03-04T13:38:21.673 | op   | event_fired    | None         | None         | None      | rhs_weap_nsvt_t90m_RWS   | None                                                               | op_1_t1_3_v1 | op_1_t1_3_u1 | rhs_mag_127x108mm_150                | rhs_weap_nsvt_t90m_RWS   | None        | 9
# 2026-03-04T13:38:21.886 | b    | event_fired    | None         | None         | None      | RHS_weap_M242BC          | None                                                               | b_1_m1_3_v1  | b_1_m1_3_u2  | rhs_mag_70Rnd_25mm_M242_APFSDS       | AP                       | None        | 8
# 2026-03-04T13:38:21.630 | op   | event_fired    | None         | None         | None      | rhs_weap_nsvt_t90m_RWS   | None                                                               | op_1_t2_2_v2 | op_1_t2_2_u3 | rhs_mag_127x108mm_150                | rhs_weap_nsvt_t90m_RWS   | None        | 8
# 2026-03-04T13:38:21.289 | b    | event_fired    | None         | None         | None      | RHS_weap_M242BC          | None                                                               | b_1_m1_3_v1  | b_1_m1_3_u2  | rhs_mag_70Rnd_25mm_M242_APFSDS       | AP                       | None        | 7
# 2026-03-04T13:38:20.047 | op   | event_fired    | None         | None         | None      | rhs_weap_2a46m_5         | None                                                               | op_1_t1_3_v1 | op_1_t1_3_u2 | rhs_mag_9m119_4                      | rhs_weap_2a46m_5         | None        | 7
# 2026-03-04T13:38:20.768 | b    | event_fired    | None         | None         | None      | RHS_M2_CROWS_M153_Abrams | None                                                               | b_1_t1_3_v1  | b_1_t1_3_u2  | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 6
# 2026-03-04T13:38:20.583 | b    | event_fired    | None         | None         | None      | RHS_M2_CROWS_M153_Abrams | None                                                               | b_1_t1_3_v1  | b_1_t1_3_u2  | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 5
# 2026-03-04T13:38:20.474 | b    | event_fired    | None         | None         | None      | RHS_M2_CROWS_M153_Abrams | None                                                               | b_1_t1_3_v1  | b_1_t1_3_u2  | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 4
# 2026-03-04T13:38:20.314 | b    | event_fired    | None         | None         | None      | RHS_M2_CROWS_M153_Abrams | None                                                               | b_1_t1_3_v1  | b_1_t1_3_u2  | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 3
# 2026-03-04T13:38:19.989 | op   | event_dammaged | op_1_t1_3_v1 | b_1_m1_3_v1  | 0.011268  | RHS_ammo_M919_APFSDS     | #light_l                                                           | None         | None         | None                                 | None                     | None        | 2
# 2026-03-04T13:38:19.988 | op   | event_dammaged | op_1_t1_3_v1 | b_1_m1_3_v1  | 0.011268  | RHS_ammo_M919_APFSDS     | #light_l                                                           | None         | None         | None                                 | None                     | None        | 1
# 2026-03-04T13:38:19.987 | op   | event_dammaged | op_1_t1_3_v1 | b_1_m1_3_v1  | 0.37407   | RHS_ammo_M919_APFSDS     | hitrtrack                                                          | None         | None         | None                                 | None                     | None        | 0
# 2026-03-04T13:38:19.772 | op   | event_fired    | None         | None         | None      | rhs_weap_nsvt_t90m_RWS   | None                                                               | op_1_t1_3_v1 | op_1_t1_3_u1 | rhs_mag_127x108mm_150                | rhs_weap_nsvt_t90m_RWS   | None        | 6
# 2026-03-04T13:38:19.696 | op   | event_fired    | None         | None         | None      | rhs_weap_2a72            | None                                                               | op_1_M1_3_v1 | op_1_m1_3_u2 | rhs_mag_3ubr11_195                   | HE                       | None        | 5
# 2026-03-04T13:38:19.622 | op   | event_fired    | None         | None         | None      | rhs_weap_nsvt_t90m_RWS   | None                                                               | op_1_t1_3_v1 | op_1_t1_3_u1 | rhs_mag_127x108mm_150                | rhs_weap_nsvt_t90m_RWS   | None        | 4
# 2026-03-04T13:38:19.499 | op   | event_fired    | None         | None         | None      | rhs_weap_nsvt_t90m_RWS   | None                                                               | op_1_t1_3_v1 | op_1_t1_3_u1 | rhs_mag_127x108mm_150                | rhs_weap_nsvt_t90m_RWS   | None        | 3
# 2026-03-04T13:38:19.835 | b    | event_fired    | None         | None         | None      | RHS_weap_M242BC          | None                                                               | b_1_m1_3_v1  | b_1_m1_3_u2  | rhs_mag_70Rnd_25mm_M242_APFSDS       | AP                       | None        | 2
# 2026-03-04T13:38:19.347 | op   | event_fired    | None         | None         | None      | rhs_weap_nsvt_t90m_RWS   | None                                                               | op_1_t1_3_v1 | op_1_t1_3_u1 | rhs_mag_127x108mm_150                | rhs_weap_nsvt_t90m_RWS   | None        | 2
# 2026-03-04T13:38:19.257 | b    | event_fired    | None         | None         | None      | RHS_weap_M242BC          | None                                                               | b_1_m1_3_v1  | b_1_m1_3_u2  | rhs_mag_70Rnd_25mm_M242_APFSDS       | AP                       | None        | 1
# 2026-03-04T13:38:19.258 | op   | event_fired    | None         | None         | None      | rhs_weap_2a72            | None                                                               | op_1_M1_3_v1 | op_1_m1_3_u2 | rhs_mag_3ubr11_195                   | HE                       | None        | 1
# 2026-03-04T13:38:18.702 | b    | event_dammaged | b_1_m1_4_u3  | op_1_t1_3_v1 | 1.0       | rhs_ammo_spall           | hitlegs                                                            | None         | None         | None                                 | None                     | None        | 70
# 2026-03-04T13:38:18.702 | b    | event_dammaged | b_1_m1_4_v1  | op_1_t1_3_v1 | 0.4       | rhs_ammo_spall           | hitengine                                                          | None         | None         | None                                 | None                     | None        | 69
# 2026-03-04T13:38:18.650 | b    | event_dammaged | b_1_m1_4_v1  | op_1_t1_3_v1 | 0.2       | rhs_ammo_spall           | hitengine,hithull                                                  | None         | None         | None                                 | None                     | None        | 68
# 2026-03-04T13:38:18.650 | b    | event_dammaged | b_1_m1_4_u2  | op_1_t1_3_v1 | 1.0       | rhs_ammo_spall           | hitface,hitabdomen,hitdiaphragm                                    | None         | None         | None                                 | None                     | None        | 65
# 2026-03-04T13:38:18.642 | b    | event_dammaged | b_1_m1_4_u2  | op_1_t1_3_v1 | 1.0       | rhs_ammo_spall           | hitdiaphragm,hitlegs                                               | None         | None         | None                                 | None                     | None        | 61
# 2026-03-04T13:38:18.641 | b    | event_dammaged | b_1_m1_4_u2  | op_1_t1_3_v1 | 1.0       | rhs_ammo_spall           | hitface,hitneck,hitpelvis,hitabdomen,hitdiaphragm,hitchest,hitlegs | None         | None         | None                                 | None                     | None        | 59
# 2026-03-04T13:38:18.641 | b    | event_dammaged | b_1_m1_4_u3  | op_1_t1_3_v1 | 1.0       | rhs_ammo_spall           | hitdiaphragm,hitarms,hithands,hitlegs,hitpelvis,hitabdomen         | None         | None         | None                                 | None                     | None        | 56
# 2026-03-04T13:38:18.641 | b    | event_dammaged | b_1_m1_4_v1  | op_1_t1_3_v1 | 0.0636363 | rhs_ammo_spall           | hithull                                                            | None         | None         | None                                 | None                     | None        | 41
# ... (showing the first 50 rows of 687 rows.)

# %% [markdown]
# 최근 발생한 이벤트 최대 10건?

# %%
print(get_events_recent_rows(10))
# Out:
# datetime                | side | event_type     | targetunit  | shooter      | damage | weapon                 | hitpoint          | unit         | gunner       | ammotype              | muzzle                 | killer | seq
# ------------------------+------+----------------+-------------+--------------+--------+------------------------+-------------------+--------------+--------------+-----------------------+------------------------+--------+----
# 2026-03-04T13:38:24.093 | op   | event_fired    | None        | None         | None   | rhs_weap_nsvt_t90m_RWS | None              | op_1_t2_2_v2 | op_1_t2_2_u3 | rhs_mag_127x108mm_150 | rhs_weap_nsvt_t90m_RWS | None   | 22
# 2026-03-04T13:38:23.375 | b    | event_dammaged | b_1_t1_3_v1 | op_1_M1_3_v1 | 1.0    | rhs_ammo_3ubr11        | #light_r          | None         | None         | None                  | None                   | None   | 3
# 2026-03-04T13:38:23.374 | b    | event_dammaged | b_1_t1_3_v1 | op_1_M1_3_v1 | 1.0    | rhs_ammo_3ubr11        | #light_l,#light_r | None         | None         | None                  | None                   | None   | 2
# 2026-03-04T13:38:23.978 | op   | event_fired    | None        | None         | None   | rhs_weap_nsvt_t90m_RWS | None              | op_1_t2_2_v2 | op_1_t2_2_u3 | rhs_mag_127x108mm_150 | rhs_weap_nsvt_t90m_RWS | None   | 21
# 2026-03-04T13:38:23.839 | op   | event_fired    | None        | None         | None   | rhs_weap_nsvt_t90m_RWS | None              | op_1_t2_2_v2 | op_1_t2_2_u3 | rhs_mag_127x108mm_150 | rhs_weap_nsvt_t90m_RWS | None   | 20
# 2026-03-04T13:38:23.692 | op   | event_fired    | None        | None         | None   | rhs_weap_nsvt_t90m_RWS | None              | op_1_t2_2_v2 | op_1_t2_2_u3 | rhs_mag_127x108mm_150 | rhs_weap_nsvt_t90m_RWS | None   | 19
# 2026-03-04T13:38:22.782 | op   | event_fired    | None        | None         | None   | rhs_weap_2a72          | None              | op_1_M1_3_v1 | op_1_m1_3_u2 | rhs_mag_3ubr11_195    | HE                     | None   | 18
# 2026-03-04T13:38:22.373 | op   | event_fired    | None        | None         | None   | rhs_weap_2a72          | None              | op_1_M1_3_v1 | op_1_m1_3_u2 | rhs_mag_3ubr11_195    | HE                     | None   | 17
# 2026-03-04T13:38:22.174 | op   | event_fired    | None        | None         | None   | rhs_weap_2a72          | None              | op_1_M1_3_v1 | op_1_m1_3_u2 | rhs_mag_3ubr11_195    | HE                     | None   | 16
# 2026-03-04T13:38:22.074 | op   | event_fired    | None        | None         | None   | rhs_weap_nsvt_t90m_RWS | None              | op_1_t2_2_v2 | op_1_t2_2_u3 | rhs_mag_127x108mm_150 | rhs_weap_nsvt_t90m_RWS | None   | 15

# %% [markdown]
# 13:30부터 13:35 사이에, 발생한 모든 이벤트?

# %%
print(get_events_between("2026-03-04T13:30:00.000", "2026-03-04T13:35:00.000"))
# Out:
# datetime                | side | event_type     | targetunit   | shooter     | damage | weapon                   | hitpoint                                                                                          | unit        | gunner      | ammotype                             | muzzle                   | killer      | seq
# ------------------------+------+----------------+--------------+-------------+--------+--------------------------+---------------------------------------------------------------------------------------------------+-------------+-------------+--------------------------------------+--------------------------+-------------+----
# 2026-03-04T13:35:00.557 | b    | event_fired    | None         | None        | None   | RHS_M2_CROWS_M153_Abrams | None                                                                                              | b_1_t1_1_v1 | b_1_t1_1_u3 | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 9
# 2026-03-04T13:35:00.335 | b    | event_fired    | None         | None        | None   | RHS_M2_CROWS_M153_Abrams | None                                                                                              | b_1_t1_1_v1 | b_1_t1_1_u3 | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 8
# 2026-03-04T13:35:00.164 | b    | event_fired    | None         | None        | None   | RHS_M2_CROWS_M153_Abrams | None                                                                                              | b_1_t1_1_v1 | b_1_t1_1_u3 | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 7
# 2026-03-04T13:34:58.683 | b    | event_fired    | None         | None        | None   | RHS_M2_CROWS_M153_Abrams | None                                                                                              | b_1_t1_1_v1 | b_1_t1_1_u3 | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 6
# 2026-03-04T13:34:58.482 | b    | event_fired    | None         | None        | None   | RHS_M2_CROWS_M153_Abrams | None                                                                                              | b_1_t1_1_v1 | b_1_t1_1_u3 | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 5
# 2026-03-04T13:34:58.378 | b    | event_fired    | None         | None        | None   | RHS_M2_CROWS_M153_Abrams | None                                                                                              | b_1_t1_1_v1 | b_1_t1_1_u3 | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 4
# 2026-03-04T13:34:58.183 | b    | event_fired    | None         | None        | None   | RHS_M2_CROWS_M153_Abrams | None                                                                                              | b_1_t1_1_v1 | b_1_t1_1_u3 | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 3
# 2026-03-04T13:34:56.624 | b    | event_fired    | None         | None        | None   | RHS_M2_CROWS_M153_Abrams | None                                                                                              | b_1_t1_1_v1 | b_1_t1_1_u3 | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 2
# 2026-03-04T13:34:56.422 | b    | event_fired    | None         | None        | None   | RHS_M2_CROWS_M153_Abrams | None                                                                                              | b_1_t1_1_v1 | b_1_t1_1_u3 | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 1
# 2026-03-04T13:34:56.235 | b    | event_fired    | None         | None        | None   | RHS_M2_CROWS_M153_Abrams | None                                                                                              | b_1_t1_1_v1 | b_1_t1_1_u3 | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 0
# 2026-03-04T13:34:54.718 | b    | event_fired    | None         | None        | None   | RHS_M2_CROWS_M153_Abrams | None                                                                                              | b_1_t1_1_v1 | b_1_t1_1_u3 | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 7
# 2026-03-04T13:34:54.519 | b    | event_fired    | None         | None        | None   | RHS_M2_CROWS_M153_Abrams | None                                                                                              | b_1_t1_1_v1 | b_1_t1_1_u3 | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 6
# 2026-03-04T13:34:54.346 | b    | event_fired    | None         | None        | None   | RHS_M2_CROWS_M153_Abrams | None                                                                                              | b_1_t1_1_v1 | b_1_t1_1_u3 | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 5
# 2026-03-04T13:34:54.247 | b    | event_fired    | None         | None        | None   | RHS_M2_CROWS_M153_Abrams | None                                                                                              | b_1_t1_1_v1 | b_1_t1_1_u3 | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 4
# 2026-03-04T13:34:52.646 | op   | event_dammaged | op_1_i1_4_u6 | b_1_t1_1_v1 | 1.0    | rhs_ammo_M829A3          | hitdiaphragm,hitchest,hithands,hitlegs,incapacitated,hitneck,hithead,hitpelvis,hitabdomen,hitbody | None        | None        | None                                 | None                     | None        | 15
# 2026-03-04T13:34:52.546 | b    | event_fired    | None         | None        | None   | RHS_M2_CROWS_M153_Abrams | None                                                                                              | b_1_t1_1_v1 | b_1_t1_1_u3 | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 3
# 2026-03-04T13:34:52.377 | b    | event_fired    | None         | None        | None   | RHS_M2_CROWS_M153_Abrams | None                                                                                              | b_1_t1_1_v1 | b_1_t1_1_u3 | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 2
# 2026-03-04T13:34:52.189 | b    | event_fired    | None         | None        | None   | RHS_M2_CROWS_M153_Abrams | None                                                                                              | b_1_t1_1_v1 | b_1_t1_1_u3 | rhs_mag_400rnd_127x99_mag_Tracer_Red | RHS_M2_CROWS_M153_Abrams | None        | 1
# 2026-03-04T13:34:52.646 | op   | event_killed   | op_1_i1_4_u6 | None        | None   | None                     | None                                                                                              | None        | None        | None                                 | None                     | b_1_t1_1_v1 | 0
# 2026-03-04T13:34:51.531 | b    | event_fired    | None         | None        | None   | rhs_weap_m256            | None                                                                                              | b_1_t1_1_v1 | b_1_t1_1_u2 | rhs_mag_M829A3                       | rhs_weap_m256            | None        | 0

# %% [markdown]
# 최근 3분간 발생한 이벤트에서 자주 등장한 유닛/장비명?

# %%
print(get_entity_frequency_recent_minutes(3))
# Out:
# entity_type | entity_name  | frequency | most_frequent_event_type | dominant_role
# ------------+--------------+-----------+--------------------------+--------------
# vehicle     | b_1_t1_3_v1  | 167       | event_fired              | attacker
# vehicle     | b_1_t1_4_v1  | 140       | event_fired              | attacker
# vehicle     | b_1_m1_3_v1  | 127       | event_dammaged           | attacker
# unit        | b_1_t1_3_u2  | 114       | event_fired              | attacker
# unit        | b_1_t1_4_u3  | 100       | event_fired              | attacker
# vehicle     | op_1_t1_3_v1 | 69        | event_dammaged           | attacker
# vehicle     | b_1_m1_2_v1  | 61        | event_dammaged           | attacker
# unit        | b_1_m1_3_u2  | 44        | event_fired              | attacker
# vehicle     | op_1_M2_1_v1 | 37        | event_dammaged           | victim
# vehicle     | op_1_M1_3_v1 | 34        | event_dammaged           | attacker
# vehicle     | b_1_m1_4_v1  | 29        | event_fired              | attacker
# unit        | b_1_m1_2_u2  | 27        | event_fired              | attacker
# vehicle     | b_1_t1_1_v1  | 23        | event_fired              | attacker
# unit        | op_1_t1_3_u1 | 22        | event_fired              | attacker
# vehicle     | op_1_t1_2_v1 | 22        | event_dammaged           | attacker
# unit        | op_1_m2_1_u3 | 22        | event_dammaged           | victim
# vehicle     | b_1_t1_2_v1  | 20        | event_dammaged           | attacker
# unit        | b_1_m1_4_u2  | 18        | event_fired              | attacker
# vehicle     | op_1_t2_1_v1 | 16        | event_dammaged           | victim
# vehicle     | op_1_t1_1_v1 | 15        | event_fired              | attacker
# unit        | op_1_t1_1_u3 | 15        | event_fired              | attacker
# unit        | op_1_m1_3_u2 | 13        | event_fired              | attacker
# unit        | b_1_t1_1_u3  | 13        | event_fired              | attacker
# unit        | b_1_t1_3_u1  | 12        | event_fired              | attacker
# unit        | op_1_t2_1_u3 | 11        | event_fired              | attacker
# unit        | op_1_i2_1_u4 | 10        | event_dammaged           | victim
# vehicle     | op_1_M1_1_v1 | 10        | event_dammaged           | attacker
# unit        | op_1_t1_2_u2 | 9         | event_fired              | attacker
# unit        | op_1_i1_4_u5 | 9         | event_dammaged           | victim
# vehicle     | op_1_t2_2_v2 | 8         | event_fired              | attacker
# unit        | op_1_t2_2_u3 | 8         | event_fired              | attacker
# vehicle     | op_1_m3_1_v1 | 8         | event_dammaged           | victim
# unit        | b_1_t1_2_u2  | 8         | event_fired              | attacker
# unit        | b_1_t1_1_u2  | 8         | event_dammaged           | victim
# vehicle     | op_1_t2_3_v1 | 7         | event_dammaged           | victim
# unit        | op_1_t2_3_u1 | 6         | event_dammaged           | victim
# unit        | op_1_m1_2_u1 | 6         | event_dammaged           | victim
# vehicle     | op_1_M2_3_v1 | 6         | event_dammaged           | victim
# unit        | op_1_m3_3_u1 | 5         | event_dammaged           | victim
# unit        | b_1_m1_4_u3  | 5         | event_dammaged           | victim
# unit        | b_1_m1_3_u3  | 5         | event_dammaged           | victim
# unit        | b_1_m1_2_u3  | 5         | event_dammaged           | victim
# unit        | op_1_t2_3_u2 | 4         | event_dammaged           | victim
# unit        | op_1_t1_3_u2 | 4         | event_fired              | attacker
# unit        | op_1_m2_1_u2 | 4         | event_fired              | attacker
# unit        | op_1_i3_2_u2 | 4         | event_dammaged           | victim
# unit        | op_1_i3_1_u1 | 4         | event_dammaged           | victim
# unit        | op_1_i1_4_u3 | 4         | event_dammaged           | victim
# unit        | op_1_i1_4_u1 | 4         | event_dammaged           | victim
# unit        | op_1_t2_1_u1 | 3         | event_dammaged           | victim
# ... (showing the first 50 rows of 75 rows.)

# %% [markdown]
# 최근 3분간 발생한 이벤트에서 자주 등장한 유닛/장비명? (Top-10)

# %%
print(get_entity_frequency_recent_minutes(3, top_k=10))
# Out:
# entity_type | entity_name  | frequency | most_frequent_event_type | dominant_role
# ------------+--------------+-----------+--------------------------+--------------
# vehicle     | b_1_t1_3_v1  | 167       | event_fired              | attacker
# vehicle     | b_1_t1_4_v1  | 140       | event_fired              | attacker
# vehicle     | b_1_m1_3_v1  | 127       | event_dammaged           | attacker
# unit        | b_1_t1_3_u2  | 114       | event_fired              | attacker
# unit        | b_1_t1_4_u3  | 100       | event_fired              | attacker
# vehicle     | op_1_t1_3_v1 | 69        | event_dammaged           | attacker
# vehicle     | b_1_m1_2_v1  | 61        | event_dammaged           | attacker
# unit        | b_1_m1_3_u2  | 44        | event_fired              | attacker
# vehicle     | op_1_M2_1_v1 | 37        | event_dammaged           | victim
# vehicle     | op_1_M1_3_v1 | 34        | event_dammaged           | attacker

# %% [markdown]
# 최근 3분간 발생한 이벤트에서 자주 등장한 유닛명? (Top-10)

# %%
print(get_entity_frequency_recent_minutes(3, top_k=10, entity_type="unit"))
# Out:
# entity_type | entity_name  | frequency | most_frequent_event_type | dominant_role
# ------------+--------------+-----------+--------------------------+--------------
# unit        | b_1_t1_3_u2  | 114       | event_fired              | attacker
# unit        | b_1_t1_4_u3  | 100       | event_fired              | attacker
# unit        | b_1_m1_3_u2  | 44        | event_fired              | attacker
# unit        | b_1_m1_2_u2  | 27        | event_fired              | attacker
# unit        | op_1_t1_3_u1 | 22        | event_fired              | attacker
# unit        | op_1_m2_1_u3 | 22        | event_dammaged           | victim
# unit        | b_1_m1_4_u2  | 18        | event_fired              | attacker
# unit        | op_1_t1_1_u3 | 15        | event_fired              | attacker
# unit        | op_1_m1_3_u2 | 13        | event_fired              | attacker
# unit        | b_1_t1_1_u3  | 13        | event_fired              | attacker

# %% [markdown]
# 최근 3분간 발생한 이벤트에서 자주 등장한 장비명? (Top-10)

# %%
print(get_entity_frequency_recent_minutes(3, top_k=10, entity_type="vehicle"))
# Out:
# entity_type | entity_name  | frequency | most_frequent_event_type | dominant_role
# ------------+--------------+-----------+--------------------------+--------------
# vehicle     | b_1_t1_3_v1  | 167       | event_fired              | attacker
# vehicle     | b_1_t1_4_v1  | 140       | event_fired              | attacker
# vehicle     | b_1_m1_3_v1  | 127       | event_dammaged           | attacker
# vehicle     | op_1_t1_3_v1 | 69        | event_dammaged           | attacker
# vehicle     | b_1_m1_2_v1  | 61        | event_dammaged           | attacker
# vehicle     | op_1_M2_1_v1 | 37        | event_dammaged           | victim
# vehicle     | op_1_M1_3_v1 | 34        | event_dammaged           | attacker
# vehicle     | b_1_m1_4_v1  | 29        | event_fired              | attacker
# vehicle     | b_1_t1_1_v1  | 23        | event_fired              | attacker
# vehicle     | op_1_t1_2_v1 | 22        | event_dammaged           | attacker
